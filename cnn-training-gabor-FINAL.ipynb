# %%
import numpy as np 
import pandas as pd 
from PIL import Image
import os

output_size = (48, 48)

# Define input and output directories
input_dir1 = r'D:\\Study\\Thesis Backup\\Thesis Codes\\kdef\\angry'
output_dir1 = r'D:\\Study\\Thesis Backup\\Thesis Codes\\kdef gray\\angry'

input_dir2 = r'D:\\Study\\Thesis Backup\\Thesis Codes\\kdef\\disgust'
output_dir2 = r'D:\\Study\\Thesis Backup\\Thesis Codes\\kdef gray\\disgust'

input_dir3 = r'D:\\Study\\Thesis Backup\\Thesis Codes\\kdef\\fear'
output_dir3 = r'D:\\Study\\Thesis Backup\\Thesis Codes\\kdef gray\\fear'

input_dir4 = r'D:\\Study\\Thesis Backup\\Thesis Codes\\kdef\\happy'
output_dir4 = r'D:\\Study\\Thesis Backup\\Thesis Codes\\kdef gray\\happy'

input_dir5 = r'D:\\Study\\Thesis Backup\\Thesis Codes\\kdef\\neutral'
output_dir5 = r'D:\\Study\\Thesis Backup\\Thesis Codes\\kdef gray\\neutral'

input_dir6 = r'D:\\Study\\Thesis Backup\\Thesis Codes\\kdef\\sad'
output_dir6 = r'D:\\Study\\Thesis Backup\\Thesis Codes\\kdef gray\\sad'

input_dir7 = r'D:\\Study\\Thesis Backup\\Thesis Codes\\kdef\\surprise'
output_dir7 = r'D:\\Study\\Thesis Backup\\Thesis Codes\\kdef gray\\surprise'

# Create output directories if they don't exist
os.makedirs(output_dir1, exist_ok=True)
os.makedirs(output_dir2, exist_ok=True)
os.makedirs(output_dir3, exist_ok=True)
os.makedirs(output_dir4, exist_ok=True)
os.makedirs(output_dir5, exist_ok=True)
os.makedirs(output_dir6, exist_ok=True)
os.makedirs(output_dir7, exist_ok=True)

# Loop through each image file in the input directories and save the grayscale images in the output directories
for filename in os.listdir(input_dir1):
    with Image.open(os.path.join(input_dir1, filename)) as img:
        img_gray = img.convert('L')
        img_gray = img_gray.resize(output_size, resample=Image.LANCZOS)
        img_gray.save(os.path.join(output_dir1, filename))

for filename in os.listdir(input_dir2):
    with Image.open(os.path.join(input_dir2, filename)) as img:
        img_gray = img.convert('L')
        img_gray = img_gray.resize(output_size, resample=Image.LANCZOS)
        img_gray.save(os.path.join(output_dir2, filename))

for filename in os.listdir(input_dir3):
    with Image.open(os.path.join(input_dir3, filename)) as img:
        img_gray = img.convert('L')
        img_gray = img_gray.resize(output_size, resample=Image.LANCZOS)
        img_gray.save(os.path.join(output_dir3, filename))

for filename in os.listdir(input_dir4):
    with Image.open(os.path.join(input_dir4, filename)) as img:
        img_gray = img.convert('L')
        img_gray = img_gray.resize(output_size, resample=Image.LANCZOS)
        img_gray.save(os.path.join(output_dir4, filename))

for filename in os.listdir(input_dir5):
    with Image.open(os.path.join(input_dir5, filename)) as img:
        img_gray = img.convert('L')
        img_gray = img_gray.resize(output_size, resample=Image.LANCZOS)
        img_gray.save(os.path.join(output_dir5, filename))

for filename in os.listdir(input_dir6):
    with Image.open(os.path.join(input_dir6, filename)) as img:
        img_gray = img.convert('L')
        img_gray = img_gray.resize(output_size, resample=Image.LANCZOS)
        img_gray.save(os.path.join(output_dir6, filename))

for filename in os.listdir(input_dir7):
    with Image.open(os.path.join(input_dir7, filename)) as img:
        img_gray = img.convert('L')
        img_gray = img_gray.resize(output_size, resample=Image.LANCZOS)
        img_gray.save(os.path.join(output_dir7, filename))

# %%
#Label extraction
import os
labels = []
for i in os.listdir(r'D:\\Study\\Thesis Backup\\Thesis Codes\\Ck+48\\anger'):
    labels.append(0)
for i in os.listdir(r'D:\\Study\\Thesis Backup\\Thesis Codes\\Ck+48\\contempt'):
    labels.append(1)
for i in os.listdir(r'D:\\Study\\Thesis Backup\\Thesis Codes\\Ck+48\\disgust'):
    labels.append(2)
for i in os.listdir(r'D:\\Study\\Thesis Backup\\Thesis Codes\\Ck+48\\fear'):
    labels.append(3)
for i in os.listdir(r'D:\\Study\\Thesis Backup\\Thesis Codes\\Ck+48\\happy'):
    labels.append(4)
for i in os.listdir(r'D:\\Study\\Thesis Backup\\Thesis Codes\\Ck+48\\sadness'):
    labels.append(5)
for i in os.listdir(r'D:\\Study\\Thesis Backup\\Thesis Codes\\Ck+48\\surprise'):
    labels.append(6)
for i in os.listdir(r'D:\\Study\\Thesis Backup\\Thesis Codes\\kdef gray\\angry'):
    labels.append(0)
for i in os.listdir(r'D:\\Study\\Thesis Backup\\Thesis Codes\\kdef gray\\disgust'):
    labels.append(2)
for i in os.listdir(r'D:\\Study\\Thesis Backup\\Thesis Codes\\kdef gray\\fear'):
    labels.append(3)
for i in os.listdir(r"D:\\Study\\Thesis Backup\\Thesis Codes\\kdef gray\\happy"):
    labels.append(4)
for i in os.listdir(r"D:\\Study\\Thesis Backup\\Thesis Codes\\kdef gray\\neutral"):
    labels.append(7)
for i in os.listdir(r"D:\\Study\\Thesis Backup\\Thesis Codes\\kdef gray\\sad"):
    labels.append(5)
for i in os.listdir(r"D:\\Study\\Thesis Backup\\Thesis Codes\\kdef gray\\surprise"):
    labels.append(6)

# %%
#feature extraction
import cv2
loc1 = r'D:\Study\Thesis Backup\Thesis Codes\Ck+48\anger'
loc2 = r'D:\Study\Thesis Backup\Thesis Codes\Ck+48\contempt'
loc3 = r'D:\Study\Thesis Backup\Thesis Codes\Ck+48\disgust'
loc4 = r'D:\Study\Thesis Backup\Thesis Codes\Ck+48\fear'
loc5 = r'D:\Study\Thesis Backup\Thesis Codes\Ck+48\happy'
loc6 = r'D:\Study\Thesis Backup\Thesis Codes\Ck+48\sadness'
loc7 = r'D:\Study\Thesis Backup\Thesis Codes\Ck+48\surprise'
loc8 = r"D:\Study\Thesis Backup\Thesis Codes\kdef gray\angry"
loc9 = r"D:\Study\Thesis Backup\Thesis Codes\kdef gray\disgust"
loc10 = r"D:\Study\Thesis Backup\Thesis Codes\kdef gray\fear"
loc11 = r"D:\Study\Thesis Backup\Thesis Codes\kdef gray\happy"
loc12 = r"D:\Study\Thesis Backup\Thesis Codes\kdef gray\neutral"
loc13 = r"D:\Study\Thesis Backup\Thesis Codes\kdef gray\sad"
loc14 = r"D:\Study\Thesis Backup\Thesis Codes\kdef gray\surprise"

features = []
from tqdm import tqdm
for i in tqdm(os.listdir(loc1)):
    features.append(cv2.imread(os.path.join(loc1,i),0))  
for i in tqdm(os.listdir(loc2)):
    features.append(cv2.imread(os.path.join(loc2,i),0))
for i in tqdm(os.listdir(loc3)):
    features.append(cv2.imread(os.path.join(loc3,i),0))
for i in tqdm(os.listdir(loc4)):
    features.append(cv2.imread(os.path.join(loc4,i),0))
for i in tqdm(os.listdir(loc5)):
    features.append(cv2.imread(os.path.join(loc5,i),0))
for i in tqdm(os.listdir(loc6)):
    features.append(cv2.imread(os.path.join(loc6,i),0))
for i in tqdm(os.listdir(loc7)):
    features.append(cv2.imread(os.path.join(loc7,i),0))
for i in tqdm(os.listdir(loc8)):
    features.append(cv2.imread(os.path.join(loc8,i),0))
for i in tqdm(os.listdir(loc9)):
    features.append(cv2.imread(os.path.join(loc9,i),0))
for i in tqdm(os.listdir(loc10)):
    features.append(cv2.imread(os.path.join(loc10,i),0))
for i in tqdm(os.listdir(loc11)):
    features.append(cv2.imread(os.path.join(loc11,i),0))
for i in tqdm(os.listdir(loc12)):
    features.append(cv2.imread(os.path.join(loc12,i),0))
for i in tqdm(os.listdir(loc13)):
    features.append(cv2.imread(os.path.join(loc13,i),0))
for i in tqdm(os.listdir(loc14)):
    features.append(cv2.imread(os.path.join(loc14,i),0))
# Out:
# ...
# 100%|██████████| 419/419 [00:00<00:00, 1261.25it/s]

# %%
labels = [0 if x in [0,1,2,5,7] else 1 for x in labels]

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPool2D, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam,RMSprop,SGD,Adamax
from tensorflow.keras import regularizers

# def create_model(input_shape=None):
#     if input_shape is None :
#         input_shape=(48,48,1)

#     model = Sequential()
#     model.add(Conv2D(6, (5, 5), input_shape=input_shape, padding='same', activation = 'relu'))
#     model.add(MaxPool2D(pool_size=(2, 2)))

#     model.add(Conv2D(16, (5, 5), padding='same', activation = 'relu'))
#     model.add(MaxPool2D(pool_size=(2, 2)))

#     model.add(Conv2D(64, (3, 3), activation = 'relu'))
#     model.add(MaxPool2D(pool_size=(2, 2)))

#     model.add(Flatten())
#     model.add(Dense(128, activation = 'relu'))
#     model.add(Dropout(0.5))
#     model.add(Dense(2, activation = 'softmax'))
    
#     return model 


def create_model(input_shape=None):
    if input_shape is None:
        input_shape = (48, 48, 1)

    model = Sequential()
    model.add(Conv2D(6, (5, 5), input_shape=input_shape, padding='same', activation='relu'))
    model.add(MaxPool2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(16, (5, 5), padding='same', activation='relu'))
    model.add(MaxPool2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPool2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax'))

    return model

# %%
import visualkeras
from PIL import ImageFont
mdl = create_model()
visualkeras.layered_view(mdl, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=576x292>

# %%
es = EarlyStopping(
    monitor='val_accuracy', min_delta=0.0001, patience=10, verbose=2,
    mode='max', baseline=None, restore_best_weights=True
)
lr = ReduceLROnPlateau(
    monitor='val_accuracy', factor=0.1, patience=5, verbose=2,
    mode='max', min_delta=1e-5, cooldown=0, min_lr=0
)

callbacks = [es, lr]

# %%
def plot_performance(history):
    plt.figure(figsize=(12, 8))

    plt.subplot(2, 1, 1)
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='val')

    plt.legend()
    plt.grid()
    plt.title('train and val loss evolution')

    plt.subplot(2, 1, 2)
    plt.plot(history.history['accuracy'], label='train')
    plt.plot(history.history['val_accuracy'], label='val')

    plt.legend()
    plt.grid()
    plt.title('train and val accuracy')

# %%
def Gabor_filter(K_size=111, Sigma=10, Gamma=1.2, Lambda=10, Psi=0, angle=0):
    # get half size
    d = K_size // 2

    # prepare kernel
    gabor = np.zeros((K_size, K_size), dtype=np.float32)

    # each value
    for y in range(K_size):
        for x in range(K_size):
            # distance from center
            px = x - d
            py = y - d

            # degree -> radian
            theta = angle / 180. * np.pi

            # get kernel x
            _x = np.cos(theta) * px + np.sin(theta) * py

            # get kernel y
            _y = -np.sin(theta) * px + np.cos(theta) * py

            # fill kernel
            gabor[y, x] = np.exp(-(_x**2 + Gamma**2 * _y**2) / (2 * Sigma**2)) * np.cos(2*np.pi*_x/Lambda + Psi)

    # kernel normalization
    gabor /= np.sum(np.abs(gabor))

    return gabor


# Use Gabor filter to act on the image
def Gabor_filtering(gray, K_size=111, Sigma=10, Gamma=1.2, Lambda=10, Psi=0, angle=0):
    # get shape
    H, W = gray.shape

    # padding
    gray = np.pad(gray, (K_size//2, K_size//2), 'edge')

    # prepare out image
    out = np.zeros((H, W), dtype=np.float32)

    # get gabor filter
    gabor = Gabor_filter(K_size=K_size, Sigma=Sigma, Gamma=Gamma, Lambda=Lambda, Psi=0, angle=angle)

    # filtering
    for y in range(H):
        for x in range(W):
            out[y, x] = np.sum(gray[y : y + K_size, x : x + K_size] * gabor)

    out = np.clip(out, 0, 255)
    out = out.astype(np.uint8)

    return out


# Use 6 Gabor filters with different angles to perform feature extraction on the image
def Gabor_process(img):
#     print(img.shape)
    # get shape
    H, W = img.shape

    # gray scale
#     gray = BGR2GRAY(img).astype(np.float32)

    # define angle
    #As = [0, 45, 90, 135]
    As = [0,30,60,90,120,150]

    # prepare pyplot
#     plt.subplots_adjust(left=0, right=1, top=1, bottom=0, hspace=0, wspace=0.2)

    out = np.zeros([H, W], dtype=np.float32)

    # each angle
    for i, A in enumerate(As):
    
        # gabor filtering
        _out = Gabor_filtering(img, K_size=11, Sigma=1.5, Gamma=1.2, Lambda=3, angle=A)
         

        # add gabor filtered image
        out += _out
        

    # scale normalization
    out = out /out.max()*255
    out = out.astype(np.uint8)

    return out

# %%
def create_Gabor_features(data):
    Feature_data = np.zeros((len(data),48,48,1))

    for i in range(len(data)):
        img = data[i]
        out = Gabor_process(img)
        out = np.expand_dims(out , axis = 2) # adding color channel
        Feature_data[i] = out/255.00

        
    return Feature_data

# %%
import matplotlib.pyplot as plt
plt.imshow(features[0]/255.0, cmap ='gray')

# %%
from sklearn.model_selection import train_test_split
feature, feature_test, label, label_test = train_test_split(features,labels,test_size=116,random_state=11)

import pandas as pd
train_data = pd.DataFrame()
test_data = pd.DataFrame()

train_data['anxiety']= label
train_data['pixel_values']= feature
test_data['anxiety']= label_test
test_data['pixel_values']= feature_test

test_data
# Out:
#      anxiety                                       pixel_values
# 0          0  [[21, 15, 0, 0, 0, 0, 0, 6, 24, 9, 60, 62, 46,...
# 1          1  [[159, 168, 169, 162, 165, 173, 169, 156, 165,...
# 2          0  [[159, 159, 159, 160, 160, 161, 161, 161, 163,...
# 3          1  [[41, 35, 36, 27, 27, 22, 12, 9, 17, 13, 11, 1...
# 4          0  [[153, 153, 153, 154, 154, 155, 155, 155, 160,...
# ..       ...                                                ...
# 111        0  [[5, 5, 7, 17, 23, 33, 62, 88, 112, 137, 156, ...
# 112        1  [[192, 192, 193, 194, 194, 195, 196, 196, 196,...
# 113        0  [[160, 160, 160, 159, 159, 158, 158, 158, 151,...
# 114        0  [[156, 156, 156, 156, 156, 156, 156, 156, 159,...
# 115        1  [[170, 170, 170, 170, 170, 170, 170, 170, 171,...
#
# [116 rows x 2 columns]

# %%
# image_features = pd.DataFrame()
# image_features['pixel_values'] = features
# image_features['labels'] = labels
# image_features.to_csv(r'G:\THESIS\dataset\preprocessed\image_features_3.csv', index=False)
# image_features.head()
# image_features.tail()

# %%
#Data Standardization
import numpy as np
from tensorflow import keras
from tensorflow.python.keras.utils.np_utils import to_categorical

# feature = np.array(feature).reshape((-1, 48, 48, 1))
# feature_test = np.array(feature_test).reshape((-1, 48, 48, 1))
 
# feature = feature/255.0
# feature_test = feature_test/255.0

label = keras.utils.to_categorical(label)
label_test = keras.utils.to_categorical(label_test)

# %%
X_train_Gabor=create_Gabor_features(feature)
X_test_Gabor=create_Gabor_features(feature_test)

X_train_Gabor.shape , X_test_Gabor.shape
# Out:
# ((3800, 48, 48, 1), (116, 48, 48, 1))

# %%
import random
sample = random.randint(100,500)
plt.subplot(1,2,1)
plt.imshow(feature[sample],cmap='gray')
plt.axis("off")
plt.subplot(1,2,2)
plt.imshow(X_train_Gabor[sample],cmap='gray')
plt.axis("off")
# Out:
# (-0.5, 47.5, 47.5, -0.5)

# %%
Gabor_model = create_model()
Gabor_model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam' )

# %%
Gabor_history = Gabor_model.fit(X_train_Gabor, label, batch_size=8 , epochs=50, validation_data = (X_test_Gabor, label_test) ,callbacks = [callbacks])
# Out:
# Epoch 1/50
# 475/475 [==============================] - 7s 13ms/step - loss: 0.6815 - accuracy: 0.5684 - val_loss: 0.6394 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 2/50
# 475/475 [==============================] - 6s 13ms/step - loss: 0.6012 - accuracy: 0.6747 - val_loss: 0.4839 - val_accuracy: 0.8190 - lr: 0.0010
# Epoch 3/50
# 475/475 [==============================] - 6s 12ms/step - loss: 0.5277 - accuracy: 0.7466 - val_loss: 0.4026 - val_accuracy: 0.8276 - lr: 0.0010
# Epoch 4/50
# 475/475 [==============================] - 6s 12ms/step - loss: 0.4680 - accuracy: 0.7829 - val_loss: 0.3988 - val_accuracy: 0.8879 - lr: 0.0010
# Epoch 5/50
# 475/475 [==============================] - 6s 12ms/step - loss: 0.4331 - accuracy: 0.8063 - val_loss: 0.3326 - val_accuracy: 0.8879 - lr: 0.0010
# Epoch 6/50
# 475/475 [==============================] - 6s 12ms/step - loss: 0.3987 - accuracy: 0.8297 - val_loss: 0.3355 - val_accuracy: 0.9052 - lr: 0.0010
# Epoch 7/50
# ...

# %%
test_true = np.argmax(label_test, axis=1)
test_pred = np.argmax(Gabor_model.predict(X_test_Gabor), axis=1)

from sklearn import metrics
# Predicted values
y_pred = test_pred
# Actual values
y_act = test_true 
# Printing the confusion matrix
# The columns will show the instances predicted for each label,
# and the rows will show the actual number of instances for each label.
print(metrics.confusion_matrix(y_act, y_pred, labels=[0,1]))
# Printing the precision and recall, among other metrics
print(metrics.classification_report(y_act, y_pred, labels=[0,1]))


import seaborn as sns

cf = metrics.confusion_matrix(y_act,y_pred)
cf_df = pd.DataFrame(cf,
                    index=[0,1],
                    columns=[0,1])
sns.heatmap(cf,annot=True)
plt.title("CNN-Gabor Model")
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
# Out:
# 4/4 [==============================] - 0s 11ms/step
# [[70  0]
#  [ 8 38]]
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95        70
#            1       1.00      0.83      0.90        46
#
#     accuracy                           0.93       116
#    macro avg       0.95      0.91      0.93       116
# weighted avg       0.94      0.93      0.93       116

# %%
plot_performance(Gabor_history)

# %%
acc = []
Gabor_acc = Gabor_model.evaluate(X_test_Gabor, label_test, verbose = 0)[1]
acc.append(Gabor_acc)
print("Gabor Accuracy :",Gabor_model.evaluate(X_test_Gabor, label_test, verbose = 0)[1])
# Out:
# Gabor Accuracy : 0.931034505367279

# %%
Gabor_model.save('D:\\Study\\Thesis Backup\\Thesis Codes\\saved models\\Gabor_model.keras')

# %%
def anxiety_analysis(anxiety):
    objects = ['Anxiety', 'Not anxiety']
    y_pos = np.arange(len(objects))
    plt.bar(y_pos, anxiety, align='center', alpha=0.9)
    plt.tick_params(axis='x', which='both', pad=10,width=4,length=10)
    plt.xticks(y_pos, objects)
    plt.ylabel('percentage')
    plt.title('disorder')
    plt.show()

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from skimage import io
from tensorflow.keras.models import load_model
import pickle
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

image_model = load_model('D:\\Study\\Thesis Backup\\Thesis Codes\\saved models\\Gabor_model.keras')
# with open(r"G:\THESIS\saved models\pickle_anxiety_xgb_model_v2.pickle", 'rb') as f:
#     text_model = pickle.load(f)

# Load and preprocess image
img_path = r"D:\\Study\\Thesis Backup\\Thesis Codes\\kdef\\happy\\88_17.jpg"
# img = Image.open(img_path)
# img_pred = predict_image(img_path)

img = load_img(img_path, color_mode="grayscale", target_size=(48, 48))
show_img=load_img(img_path, grayscale=False, target_size=(200, 200))
x = img_to_array(img)
x = np.expand_dims(x, axis = 0)

# x /= 255.0

img_pred = image_model.predict(x)
    
anxiety_analysis(img_pred[0])

x = np.array(x, 'float32')
x = x.reshape([48, 48]);

print(img_pred)
plt.gray()
plt.imshow(show_img)
plt.show()

m=0.000000000000000000001
a=img_pred[0]
for i in range(0,len(a)):
    if a[i]>m:
        m=a[i]
        ind=i
# Out:
# 1/1 [==============================] - 0s 96ms/step
# [[0. 1.]]

# %%
print(image_model.predict(X_test_Gabor))
# Out:
# 4/4 [==============================] - 0s 11ms/step
# [[9.16917503e-01 8.30824226e-02]
#  [1.35068133e-01 8.64931941e-01]
#  [7.38212109e-01 2.61787981e-01]
#  [2.77605262e-02 9.72239494e-01]
#  [9.33365881e-01 6.66341037e-02]
#  [5.53401280e-03 9.94466007e-01]
#  [7.97025740e-01 2.02974334e-01]
#  [9.69420850e-01 3.05791795e-02]
#  [9.94676352e-01 5.32370200e-03]
#  [9.55305040e-01 4.46949787e-02]
#  [1.12527110e-01 8.87472928e-01]
#  [8.02290514e-02 9.19770956e-01]
#  [3.13535780e-02 9.68646467e-01]
#  [9.49828923e-01 5.01710586e-02]
#  [9.97423530e-01 2.57651601e-03]
#  [9.94225681e-01 5.77439927e-03]
#  [7.00966299e-01 2.99033701e-01]
#  [5.17784730e-02 9.48221564e-01]
#  [9.92532969e-01 7.46698072e-03]
#  [7.49347284e-02 9.25065219e-01]
#  [2.19724804e-01 7.80275166e-01]
#  [6.39046729e-01 3.60953212e-01]
#  [1.13912169e-02 9.88608837e-01]
#  [9.22671914e-01 7.73281381e-02]
#  [1.10313460e-01 8.89686525e-01]
#  [9.93052423e-01 6.94753788e-03]
#  [6.00079775e-01 3.99920166e-01]
# ...

# %%
img_pred_csv = image_model.predict(X_test_Gabor)
# Out:
# 4/4 [==============================] - 0s 10ms/step

# %%
img_anxiety = img_pred_csv[:,0]
img_not_anxiety = img_pred_csv[:,1]

# %%
fusion_csv = pd.DataFrame()
fusion_csv['img anxiety p'] = img_anxiety*100
fusion_csv['img not anxiety p'] = img_not_anxiety*100

fusion_csv.to_csv(r'D:\\Study\\Thesis Backup\\Thesis Codes\\fusion dataset\\fusion_csv.csv', index=False)
fusion_csv
# Out:
#      img anxiety p  img not anxiety p
# 0        91.691750           8.308242
# 1        13.506813          86.493195
# 2        73.821213          26.178799
# 3         2.776053          97.223953
# 4        93.336586           6.663410
# ..             ...                ...
# 111      95.883224           4.116768
# 112      69.276009          30.723995
# 113      71.797035          28.202967
# 114      96.150963           3.849032
# 115      27.235550          72.764450
#
# [116 rows x 2 columns]

# %%
fusion_csv
# Out:
#      img anxiety p  img not anxiety p
# 0        91.691750           8.308242
# 1        13.506813          86.493195
# 2        73.821213          26.178799
# 3         2.776053          97.223953
# 4        93.336586           6.663410
# ..             ...                ...
# 111      95.883224           4.116768
# 112      69.276009          30.723995
# 113      71.797035          28.202967
# 114      96.150963           3.849032
# 115      27.235550          72.764450
#
# [116 rows x 2 columns]
